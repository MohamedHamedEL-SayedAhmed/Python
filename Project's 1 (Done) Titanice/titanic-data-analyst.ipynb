# %% [markdown]
# # <p style="background-color:#00FF00;font-family:newtimeroman;color:black;font-size:130%;text-align:center;border-radius:10px 10px;"> "  Mohamed Hamed "Data Analyst" " </p>
# <div style="text-align: center;">
#     <span style="font-size: 5em;">✔️</span>
# </div>
#
# <br>
#
# <div style="text-align: center;">
#    <span style="font-size: 1.4em; font-weight: bold; font-family: Arial; max-width:1200px; display: inline-block;">
#
#    </span>
# </div>
#
# <br>
#
# <br>
#
# <div style="text-align: center;">
#    <span style="font-size: 1.6em; font-weight: bold;font-family: Arial;"><a href="https://www.linkedin.com/in/mohamed-hamed-el-sayed-925a3824a/">"Linked In" Mohamed Hamed</a></span>
# </div>

# %% [markdown]
# # <p style="background-color:#FFC0CB;font-family:newtimeroman;color:black;font-size:200%;text-align:center;border-radius:10px 10px;"> !!  Import Libraries  !! </p>

# %%
import numpy as np
import pandas as pd
# Import Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from pandas.plotting import parallel_coordinates, andrews_curves, radviz
# Clustering
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # <p style="background-color:#ffb703;font-family:newtimeroman;color:black;font-size:140%;text-align:center;border-radius:10px 10px;">!! Load the dataset !!</p>

# %%
titanic = pd.read_csv("/kaggle/input/titanic/test.csv")
titanic = pd.read_csv("/kaggle/input/titanic/train.csv")

# %% [markdown]
# # <p style="background-color:#8338ec;font-family:newtimeroman;color:black;font-size:140%;text-align:center;border-radius:10px 10px;">!! Overview Of The DataSet !!</p>

# %%
# Display the first few rows
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #086375; font-size: 100%; text-align: left;">
#     📊This code is using the, <b style='color:#0000ff'>head()</b>.  function to display the first few rows of the Titanic dataset. The 'head()'function is a convenient way to quickly examine the structure and contents of a DataFrame in pandas. By default, it displays the first 5 rows, but you can specify a different number within the parentheses to display a different number of rows.. 🧐🔍
# </div>

# %%
# Check the summary statistics of the dataset
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #ffd6ba; font-size: 100%; text-align: left;">
#     📊This code is using the ''describe()'' function to calculate summary statistics of the Titanic dataset. The `describe()` function provides statistical information such as count, mean, standard deviation, minimum value, 25th percentile, median, 75th percentile, and maximum value for each numerical column in the DataFrame. It is a useful tool to get a quick overview of the distribution and range of values in the dataset. 🧐🔍
# </div>

# %%
# Information about the dataset
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #f4b942; font-size: 100%; text-align: left;">
#     📊This code is using the info() function to display information about the Titanic dataset. The info() function provides a concise summary of the DataFrame, including the number of rows, number of columns, column names, data types of each column, and the number of non-null values in each column. It is a helpful way to understand the structure and data types of the dataset, as well as identify any missing values.. 🧐🔍
# </div>

# %%
# Check the data types of each column
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #4d9078; font-size: 100%; text-align: left;">
#     📊This code is using the dtypes attribute to display the data types of each column in the Titanic dataset. The dtypes attribute returns a Series object that contains the data types of each column. It is useful to quickly check the data types of the columns in the DataFrame, which can help in understanding the nature of the data and in performing appropriate data manipulations or transformations if needed... 🧐🔍
# </div>

# %%
# Handle duplicates
duplicate_rows_data = titanic[titanic.duplicated()]
print("number of duplicate rows: ", duplicate_rows_data.shape)
# Out:
# number of duplicate rows:  (0, 12)

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #b4436c; font-size: 100%; text-align: left;">
#     📊This code checks for duplicate rows in the titanic dataset and prints the number of duplicate rows found.
#
# The titanic.duplicated() function is used to identify duplicate rows in the dataset. It returns a boolean Series where True indicates a duplicate row and False indicates a unique row.
#
# The duplicate_rows_data variable stores the duplicate rows by using boolean indexing on the titanic dataset.
#
# Finally, the shape attribute is used to get the dimensions of the duplicate_rows_data DataFrame, which gives the number of duplicate rows found.... 🧐🔍
# </div>
# ​

# %% [markdown]
# # <p style="background-color:#00bbf9;font-family:newtimeroman;color:black;font-size:140%;text-align:center;border-radius:10px 10px;">!! Data Cleaning and preprocessing !!</p>

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #5465ff; font-size: 100%; text-align: left;">
#     📊To perform data cleaning and preprocessing, you can use various techniques and functions depending on the specific requirements of your dataset. Here are some common steps involved in data cleaning and preprocessing:
#
# 1. Handling missing values: Identify and handle missing values in the dataset. You can use functions like `isnull()` to check for missing values and `fillna()` to fill or impute missing values.
#
# 2. Removing duplicates: Identify and remove duplicate rows from the dataset using the `duplicated()` function. You can drop duplicate rows using the `drop_duplicates()` function.
#
# 3. Removing outliers: Identify and handle outliers in the dataset. You can use statistical methods like the Z-score or the IQR method to detect outliers and then remove or transform them.
#
# 4. Standardizing or normalizing data: Standardize or normalize numeric data to bring them to a common scale. You can use functions like `StandardScaler()` or `MinMaxScaler()` for this purpose.
#
# 5. Categorical data encoding: Convert categorical variables into numerical representations to make them suitable for analysis. You can use techniques like one-hot encoding or label encoding for this purpose.
#
# 6. Feature scaling: Scale numeric features to ensure they have similar ranges. This is important for algorithms that are sensitive to feature scales, such as regression or clustering algorithms. You can use techniques like standardization or normalization for feature scaling.
#
# 7. Handling outliers: Identify and handle outliers in the dataset. You can use statistical methods like the Z-score or the IQR method to detect outliers and then remove or transform them...... 🧐🔍
# </div>
# ​

# %%
# Check for missing values
print(titanic.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #e2a0ff; font-size: 100%; text-align: left;">
#     📊This code checks for missing values in the `titanic` dataset and prints the sum of missing values for each column.
#
# 1-The `isnull()` function is used to identify missing values in the dataset. It returns a boolean DataFrame where `True` indicates a missing value and `False` indicates a non-missing value.
#
# 1-The `sum()` function is then applied on the boolean DataFrame to calculate the sum of `True` values for each column. Since `True` is considered as 1 and `False` as 0 in numerical calculations, the sum of `True` values gives the count of missing values in each column.
# ...... 🧐🔍
# </div>
# •

# %%
# Identify missing values
missing_values = titanic.isnull().sum() 
missing_values# Fill missing values in the 'Age' column with the median age
titanic['Age'].fillna(titanic['Age'].median(), inplace=True)

# Fill missing values in the 'Embarked' column with the most common value
titanic['Embarked'].fillna(titanic['Embarked'].mode()[0], inplace=True)

# Fill missing values in the 'Cabin' column with the most common value
titanic['Cabin'].fillna(titanic['Cabin'].mode()[0], inplace=True)

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #39a9db; font-size: 100%; text-align: left;">
#  1-This code performs missing value imputation for the `Age`, `Embarked`, and `Cabin` columns in the `titanic` dataset.
#
# 2-First, the code calculates the number of missing values in each column using the `isnull().sum()` function and stores the result in the `missing_values` variable.
#
# 3-Next, the missing values in the `Age` column are filled with the median age using the `fillna()` function. The `fillna()` function replaces missing values with the specified value, in this case, the median age of the column.
#
# 4-Similarly, missing values in the `Embarked` column are filled with the most common value using the `fillna()` function and the `mode()` function. The `mode()` function returns the most frequently occurring value in a column.
#
# 5-Lastly, missing values in the `Cabin` column are filled with the most common value using the same approach as the `Embarked` column.
#
# 6-The `inplace=True` parameter is used to modify the `titanic` DataFrame in place, without creating a new DataFrame.. 🧐🔍
# </div>
# •

# %%
#Verify if missing values have been handled
print(titanic.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #f26419; font-size: 100%; text-align: left;">
# 📊This code checks for missing values in the `titanic` dataset after performing the missing value imputation.
#
# 1-The `isnull()` function is used to identify missing values in the dataset. It returns a boolean DataFrame where `True` indicates a missing value and `False` indicates a non-missing value.
#
# 2-The `sum()` function is then applied on the boolean DataFrame to calculate the sum of `True` values for each column. Since `True` is considered as 1 and `False` as 0 in numerical calculations, the sum of `True` values gives the count of missing values in each column.🧐🔍
# </div>

# %%
 # Fill missing values in the 'Age' column with median age
titanic['Age'].fillna(titanic['Age'].median(), inplace=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #add7f6; font-size: 100%; text-align: left;">
# 📊This code fills the missing values in the 'Age' column of the 'titanic' dataset with the median age value.
#
# 1-The `fillna()` function is used to fill missing values in the 'Age' column. The `fillna()` function replaces missing values with the specified value, in this case, the median age of the 'Age' column which is calculated using `titanic['Age'].median()`.
#
# 2-The `inplace=True` parameter is used to modify the 'titanic' DataFrame in place, without creating a new DataFrame..🧐🔍
# </div>

# %%
 # Fill missing values in the 'Embarked' column with mode
titanic['Embarked'].fillna(titanic['Embarked'].mode()[0], inplace=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #e8ffb7; font-size: 100%; text-align: left;">
# 📊This code fills the missing values in the 'Embarked' column of the 'titanic' dataset with the mode (most common value) of the column.
#
# 1-The `fillna()` function is used to fill missing values in the 'Embarked' column. The `fillna()` function replaces missing values with the specified value, in this case, the mode of the 'Embarked' column which is calculated using `titanic['Embarked'].mode()[0]`. The `mode()` function returns the most frequently occurring value in a column.
#
# 2-The `inplace=True` parameter is used to modify the 'titanic' DataFrame in place, without creating a new DataFrame..🧐🔍
# </div>

# %%
 # Convert categorical variables into dummy variables
titanic = pd.get_dummies(titanic, columns=['Sex', 'Embarked'], drop_first=True)

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #f6ae2d; font-size: 100%; text-align: left;">
# 📊This code converts categorical variables into dummy variables in the 'titanic' dataset.
#
# 1-The `pd.get_dummies()` function is used to create dummy variables for categorical variables. The function takes the 'titanic' dataset as the first argument and the columns to be converted into dummy variables as the second argument, specified within a list (`['Sex', 'Embarked']` in this case).
#
# 2-The `drop_first=True` parameter is used to drop the first level of each categorical variable after creating the dummy variables. This is done to avoid multicollinearity, where one category can be inferred from the others.
#
# 3-The resulting dummy variables are then assigned back to the 'titanic' DataFrame, overwriting the original columns.
#
# 4-This process effectively converts categorical variables like 'Sex' and 'Embarked' into numerical dummy variables, making them suitable for analysis in machine learning models..🧐🔍
# </div>

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %% [markdown]
# # <p style="background-color:#fee440;font-family:newtimeroman;color:black;font-size:140%;text-align:center;border-radius:10px 10px;">!! Exploratory Data Analysis !!</p>

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #cfcfea; font-size: 100%; text-align: left;">
# 📊The provided code snippet does not contain any specific code for exploratory data analysis (EDA). However, EDA typically involves various data exploration and visualization techniques to gain insights and understand the dataset. Here are some common techniques used in EDA:
#
# 1. Descriptive statistics: This involves calculating basic statistics such as mean, median, standard deviation, etc., to summarize the dataset.
#
# 2. Data visualization: This includes creating plots, charts, and graphs to visualize the distribution, relationships, and patterns in the data. Common visualization techniques include histograms, scatter plots, bar charts, box plots, etc.
#
# 3. Data profiling: This involves analyzing the structure and properties of the dataset, such as the number of rows and columns, data types, missing values, unique values, etc.
#
# 4. Correlation analysis: This involves calculating correlation coefficients between variables to understand the strength and direction of their relationships.
#
# 5. Outlier detection: This involves identifying and handling any outliers or extreme values in the dataset.
#
# 6. Feature engineering: This involves creating new variables or transforming existing variables to better represent the underlying patterns in the data..🧐🔍
# </div>

# %%
sns.countplot(x='Survived', data=titanic)
plt.title('Survival Count')
plt.show()

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #bff0d4; font-size: 100%; text-align: left;">
# 1-This code snippet uses the seaborn library (`sns`) to create a countplot of the 'Survived' variable in the 'titanic' dataset.
#
# 2-The `countplot()` function from seaborn is used to create a bar plot that shows the count of observations in each category of the specified variable. In this case, the 'Survived' variable is plotted on the x-axis.
#
# 3-The `x='Survived'` argument specifies that the 'Survived' column from the 'titanic' dataset should be plotted.
#
# 4-The `data=titanic` argument specifies the dataset from which the variable should be taken.
#
# 5-The `plt.title('Survival Count')` function sets the title of the plot to 'Survival Count'.
#
# 6-Finally, the `plt.show()` function is used to display the resulting plot.
#
# 7-This code is useful for visualizing the distribution of the 'Survived' variable, which is a binary variable indicating whether a passenger survived (1) or did not survive (0) the Titanic disaster. The countplot provides a quick overview of the number of survivors and non-survivors in the dataset..🧐🔍
# </div>

# %%
sns.countplot(x='Survived', data=titanic)
plt.title('Survival Count')
plt.show()

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #ffafcc; font-size: 100%; text-align: left;">
# 📊This code snippet uses the seaborn library (`sns`) to create a countplot of the 'Survived' variable in the 'titanic' dataset.
#
# 2-The `countplot()` function from seaborn is used to create a bar plot that shows the count of observations in each category of the specified variable. In this case, the 'Survived' variable is plotted on the x-axis.
#
# 3-The `x='Survived'` argument specifies that the 'Survived' column from the 'titanic' dataset should be plotted.
#
# 4-The `data=titanic` argument specifies the dataset from which the variable should be taken.
#
# 5-The `plt.title('Survival Count')` function sets the title of the plot to 'Survival Count'.
#
# 6-Finally, the `plt.show()` function is used to display the resulting plot.
#
# 7-This code is useful for visualizing the distribution of the 'Survived' variable, which is a binary variable indicating whether a passenger survived (1) or did not survive (0) the Titanic disaster. The countplot provides a quick overview of the number of survivors and non-survivors in the dataset..🧐🔍
# </div>

# %%
sns.countplot(x='Survived', hue='Sex_male', data=titanic)
plt.title('Survival Count by Sex_male')
plt.show()

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #e3d5ca; font-size: 100%; text-align: left;">
# 📊This code snippet uses the seaborn library (`sns`) to create a countplot of the 'Survived' variable in the 'titanic' dataset, with the data further categorized by the 'Sex_male' variable.
#
# 1-The `countplot()` function from seaborn is used to create a bar plot that shows the count of observations in each category of the specified variable. In this case, the 'Survived' variable is plotted on the x-axis, and the 'Sex_male' variable is used to further categorize the data.
#
# 2-The `x='Survived'` argument specifies that the 'Survived' column from the 'titanic' dataset should be plotted.
#
# 3-The `hue='Sex_male'` argument specifies that the 'Sex_male' column from the 'titanic' dataset should be used to categorize the data. This means that the bars in the plot will be further divided based on the gender of the passengers.
#
# 4-The `data=titanic` argument specifies the dataset from which the variables should be taken.
#
# 5-The `plt.title('Survival Count by Sex_male')` function sets the title of the plot to 'Survival Count by Sex_male'.
#
# 6-Finally, the `plt.show()` function is used to display the resulting plot.
#
# -This code is useful for visualizing the distribution of the 'Survived' variable, with the added information of the gender of the passengers. It provides insights into the survival count based on gender, allowing for a comparison of the survival rates between male and female passengers..🧐🔍
# </div>

# %%
sns.countplot(x='Survived', hue='Pclass', data=titanic)
plt.title('Survival Count by Passenger Class')
plt.show()

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #c1121f; font-size: 100%; text-align: left;">
# 📊This code snippet uses the seaborn library (`sns`) to create a countplot of the 'Survived' variable in the 'titanic' dataset, with the data further categorized by the 'Pclass' variable.
#
# 1-The `countplot()` function from seaborn is used to create a bar plot that shows the count of observations in each category of the specified variable. In this case, the 'Survived' variable is plotted on the x-axis, and the 'Pclass' variable is used to further categorize the data.
#
# 2-The `x='Survived'` argument specifies that the 'Survived' column from the 'titanic' dataset should be plotted.
#
# 3-The `hue='Pclass'` argument specifies that the 'Pclass' column from the 'titanic' dataset should be used to categorize the data. This means that the bars in the plot will be further divided based on the passenger class.
#
# 4-The `data=titanic` argument specifies the dataset from which the variables should be taken.
#
# 5-The `plt.title('Survival Count by Passenger Class')` function sets the title of the plot to 'Survival Count by Passenger Class'.
#
# 6-Finally, the `plt.show()` function is used to display the resulting plot.
#
# -This code is useful for visualizing the distribution of the 'Survived' variable, with the added information of the passenger class. It provides insights into the survival count based on different passenger classes, allowing for a comparison of the survival rates between different classes..🧐🔍
# </div>

# %%
sns.boxplot(x='Survived', y='Age', data=titanic)
plt.title('Age Distribution of Survived vs Not Survived')
plt.show()

# %% [markdown]
#  <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #1d3557; font-size: 100%; text-align: left;">
# 📊This code snippet uses the seaborn library (`sns`) to create a boxplot of the 'Age' variable in the 'titanic' dataset, with the data further categorized by the 'Survived' variable.
#
# 1-The `boxplot()` function from seaborn is used to create a box-and-whisker plot that shows the distribution of values in each category of the specified variables. In this case, the 'Age' variable is plotted on the y-axis, and the 'Survived' variable is used to categorize the data on the x-axis.
#
# 2-The `x='Survived'` argument specifies that the 'Survived' column from the 'titanic' dataset should be plotted on the x-axis.
#
# 3-The `y='Age'` argument specifies that the 'Age' column from the 'titanic' dataset should be plotted on the y-axis.
#
# 4-The `data=titanic` argument specifies the dataset from which the variables should be taken.
#
# 5-The `plt.title('Age Distribution of Survived vs Not Survived')` function sets the title of the plot to 'Age Distribution of Survived vs Not Survived'.
#
# 6-Finally, the `plt.show()` function is used to display the resulting plot.
#
# -This code is useful for visualizing the distribution of age for passengers who survived versus those who did not survive. The boxplot provides information about the median, quartiles, and any outliers in the age distribution for each survival category. It allows for a comparison of the age distributions between survivors and non-survivors..🧐🔍
# </div>

# %% [markdown]
# # <p style="background-color:#fbff12;font-family:newtimeroman;color:black;font-size:140%;text-align:center;border-radius:10px 10px;">!! Data Analysis !!</p>

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #ffba08; font-size: 100%; text-align: left;">
# 📊To perform data analysis, you would typically need to import the necessary libraries, load the dataset, clean and preprocess the data, perform exploratory data analysis (EDA), and apply statistical techniques or machine learning algorithms depending on the goals of your analysis..🧐🔍
# </div>

# %%
# Survival rate by sex
print(titanic.groupby(['Sex_male'])['Survived'].mean())
# Out:
# Sex_male
# False    0.742038
# True     0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #f72585; font-size: 100%; text-align: left;">
# 📊This code snippet calculates the survival rate based on gender using the 'titanic' dataset.
#
# 1-The `groupby()` function is used to group the data by the 'Sex_male' column. The `['Survived'].mean()` part calculates the mean of the 'Survived' column within each group.
#
# 2-The resulting output will show the survival rate for each gender. The survival rate represents the proportion of passengers who survived within each gender category.
#
# 3-For example, if the output is:
#
# Sex_male
# 0    0.742038
# 1    0.188908
# Name: Survived, dtype: float64
#
# -It means that the survival rate for females (Sex_male=0) is approximately 74.2%, while the survival rate for males (Sex_male=1) is approximately 18.9%..🧐🔍
# </div>

# %%
#Survival rate by passenger class
print(titanic.groupby(['Pclass'])['Survived'].mean())
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #fcf6bd; font-size: 100%; text-align: left;">
# 📊This code snippet calculates the survival rate based on passenger class using the 'titanic' dataset.
#
# -The `groupby()` function is used to group the data by the 'Pclass' column. The `['Survived'].mean()` part calculates the mean of the 'Survived' column within each group.
#
# -The resulting output will show the survival rate for each passenger class. The survival rate represents the proportion of passengers who survived within each class category.
#
# -For example, if the output is:
#
# -Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64
#
# -It means that the survival rate for passengers in first class (Pclass=1) is approximately 62.9%, for second class (Pclass=2) is approximately 47.3%, and for third class (Pclass=3) is approximately 24.2%..🧐🔍
# </div>

# %%
# Survival rate by port of embarkation
print(titanic.groupby(['Embarked_S'])['Survived'].mean())
print(titanic.groupby(['Embarked_Q'])['Survived'].mean())
# Out:
# Embarked_S
# False    0.502041
# True     0.339009
# Name: Survived, dtype: float64
# Embarked_Q
# False    0.383292
# True     0.389610
# Name: Survived, dtype: float64

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #a9def9; font-size: 100%; text-align: left;">
# 📊This code snippet calculates the survival rate based on the port of embarkation using the 'titanic' dataset.
#
# -The `groupby()` function is used to group the data by the 'Embarked_S' and 'Embarked_Q' columns respectively. The `['Survived'].mean()` part calculates the mean of the 'Survived' column within each group.
#
# -The resulting output will show the survival rate for each port of embarkation. The survival rate represents the proportion of passengers who survived within each port category.
#
# -For example, if the output is:
#
# -Embarked_S
# 0    0.336957
# 1    0.638817
# Name: Survived, dtype: float64
#
# -Embarked_Q
# 0    0.382609
# 1    0.389610
# Name: Survived, dtype: float64
#
# -It means that the survival rate for passengers who embarked from Southampton (Embarked_S=0) is approximately 33.7%, while the survival rate for passengers who embarked from Cherbourg (Embarked_S=1) is approximately 63.9%.
#
# -Similarly, the survival rate for passengers who embarked from Queenstown (Embarked_Q=0) is approximately 38.3%, while the survival rate for passengers who embarked from Cherbourg (Embarked_Q=1) is approximately 38.9%..🧐🔍
# </div>

# %% [markdown]
# # <p style="background-color:#41ead4;font-family:newtimeroman;color:black;font-size:140%;text-align:center;border-radius:10px 10px;">!! Feature Engineering !!</p>

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #bc4749; font-size: 100%; text-align: left;">
# 📊Feature engineering involves creating new features or transforming existing features in a dataset to improve the performance of a machine learning model or gain better insights from the data. Here's an example of feature engineering code:
#
# 1. Create new features:
# python
# # Example: Create a new feature 'FamilySize' by combining 'SibSp' and 'Parch' features
# df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
# 2. Transform existing features:
# python
# # Example: Apply log transformation to 'Age' feature
# df['Age_log'] = np.log(df['Age'])
# 3. Binning or discretizing continuous variables:
# python
# # Example: Bin 'Age' into different age groups
# bins = [0, 18, 30, 50, 100]
# labels = ['Child', 'Young Adult', 'Adult', 'Senior']
# df['Age_group'] = pd.cut(df['Age'], bins=bins, labels=labels)
# 4. Encoding categorical variables:
# python
# # Example: One-hot encoding for 'Embarked' feature
# df_encoded = pd.get_dummies(df['Embarked'], prefix='Embarked')
# df = pd.concat([df, df_encoded], axis=1)
# 5. Feature scaling:
# python
# # Example: Standardize 'Fare' feature using z-score normalization
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# df['Fare_scaled'] = scaler.fit_transform(df['Fare'].values.reshape(-1, 1))
# These are just a few examples of feature engineering techniques. The specific feature engineering methods you choose will depend on the dataset, the problem you are trying to solve, and the algorithms you plan to use for analysis or modeling..🧐🔍
# </div>

# %%
#Create a new feature 'FamilySize'
titanic['FamilySize'] = titanic['SibSp'] + titanic['Parch'] + 1
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #ff9f1c; font-size: 100%; text-align: left;">
# 📊This code snippet creates a new feature called 'FamilySize' in the 'titanic' dataset. The 'FamilySize' feature is created by adding the 'SibSp' (number of siblings/spouses aboard) and 'Parch' (number of parents/children aboard) features together and then adding 1 to account for the passenger themselves.
#
# The code `titanic['FamilySize'] = titanic['SibSp'] + titanic['Parch'] + 1` assigns the sum of 'SibSp', 'Parch', and 1 to the 'FamilySize' column in the 'titanic' dataframe.
#
# The resulting 'titanic' dataframe will now have an additional column named 'FamilySize' that represents the total number of family members (including the passenger) aboard the Titanic for each passenger..🧐🔍
# </div>

# %%
# Survival rate by family size
print(titanic.groupby(['FamilySize'])['Survived'].mean())
# Out:
# FamilySize
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #80ffdb; font-size: 100%; text-align: left;">
# 📊This code snippet calculates the survival rate based on family size using the 'titanic' dataset.
#
# The `groupby()` function is used to group the data by the 'FamilySize' column. The `['Survived'].mean()` part calculates the mean of the 'Survived' column within each group.
#
# The resulting output will show the survival rate for each family size. The survival rate represents the proportion of passengers who survived within each family size category.
#
# For example, if the output is:
#
# FamilySize
# 1    0.303538
# 2    0.552795
# 3    0.578431
# 4    0.724138
# 5    0.200000
# 6    0.136364
# 7    0.333333
# 8    0.000000
# 11   0.000000
# Name: Survived, dtype: float64
#
# It means that the survival rate for passengers who were alone (FamilySize=1) is approximately 30.4%, for passengers with a family size of 2 is approximately 55.3%, for passengers with a family size of 3 is approximately 57.8%, and so on.
#
# Passengers with larger family sizes (e.g., 8 or 11) have a survival rate of 0%, indicating that none of them survived..🧐🔍
# </div>

# %%
#Create a new feature 'IsAlone'
titanic['IsAlone'] = 0

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #ff0054; font-size: 100%; text-align: left;">
# 📊This code snippet creates a new feature called 'IsAlone' in the 'titanic' dataset and initializes it with a value of 0 for all passengers.
#
# 1-The code `titanic['IsAlone'] = 0` assigns the value 0 to the 'IsAlone' column in the 'titanic' dataframe for all rows.
#
# 2-The 'IsAlone' feature can be used to indicate whether a passenger was traveling alone or with family members. The value 0 typically represents that the passenger is not alone, while the value 1 can be used to indicate that the passenger is traveling alone.
#
# -After assigning the initial value of 0 to all passengers, you can further update the 'IsAlone' feature based on the 'FamilySize' feature. For example, if 'FamilySize' is 1, you can set 'IsAlone' to 1 to indicate that the passenger is traveling alone..🧐🔍
# </div>

# %%
titanic.loc[titanic['FamilySize'] == 1, 'IsAlone'] = 1
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #00bbf9; font-size: 100%; text-align: left;">
# 1-This code snippet updates the 'IsAlone' feature in the 'titanic' dataset based on the 'FamilySize' feature. It sets the value of 'IsAlone' to 1 for passengers who have a 'FamilySize' of 1, indicating that they are traveling alone.
#
# 2-The code `titanic.loc[titanic['FamilySize'] == 1, 'IsAlone'] = 1` uses the `loc` function to select rows where the 'FamilySize' column is equal to 1. Then, it assigns the value 1 to the corresponding 'IsAlone' column for those rows.
#
# 3-The resulting 'titanic' dataframe will now have an updated 'IsAlone' column, where passengers with a 'FamilySize' of 1 will have a value of 1 in the 'IsAlone' column, indicating that they are traveling alone. Other passengers will still have a value of 0 in the 'IsAlone' column, indicating that they are not traveling alone..🧐🔍
# </div>

# %%
#Survival rate by alone or not
print(titanic.groupby(['IsAlone'])['Survived'].mean())
# Out:
# IsAlone
# 0    0.505650
# 1    0.303538
# Name: Survived, dtype: float64

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #00f5d4; font-size: 100%; text-align: left;">
# 📊This code snippet calculates the survival rate based on whether a passenger is traveling alone or not using the 'titanic' dataset.
#
# -The `groupby()` function is used to group the data by the 'IsAlone' column. The `['Survived'].mean()` part calculates the mean of the 'Survived' column within each group.
#
# -The resulting output will show the survival rate for passengers who are traveling alone and passengers who are not traveling alone.
#
# -For example, if the output is:
#
# --IsAlone
# 0    0.505650
# 1    0.303538
# Name: Survived, dtype: float64
#
# -It means that the survival rate for passengers who are not traveling alone (IsAlone=0) is approximately 50.6%, while the survival rate for passengers who are traveling alone (IsAlone=1) is approximately 30.4%.
#
# -This information can be useful in understanding the impact of traveling alone or with family members on the likelihood of survival during the Titanic disaster..🧐🔍
# </div>

# %% [markdown]
# # <p style="background-color:#f15bb5;font-family:newtimeroman;color:black;font-size:140%;text-align:center;border-radius:10px 10px;">!! Data Visualization !!</p>

# %%
sns.boxplot(x='Survived', y='Fare', data=titanic)
plt.title('Fare Distribution of Survived vs Not Survived')
plt.show()

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #9b5de5; font-size: 100%; text-align: left;">
# 📊This code snippet uses the Seaborn library to create a box plot to compare the fare distribution between passengers who survived and those who did not survive in the 'titanic' dataset.
#
# -The code `sns.boxplot(x='Survived', y='Fare', data=titanic)` creates a box plot using the Seaborn `boxplot()` function. The 'Survived' column is used as the x-axis variable, and the 'Fare' column is used as the y-axis variable. The 'titanic' dataset is specified as the data source.
#
# -The code `plt.title('Fare Distribution of Survived vs Not Survived')` adds a title to the plot.
#
# -Finally, `plt.show()` is used to display the plot.
#
# -The resulting plot will show two boxes side by side, representing the fare distribution for passengers who survived and those who did not survive. This visualization can help identify if there are any differences in fare distribution between the two groups and provide insights into the relationship between fare and survival..🧐🔍
# </div>

# %%
# Bar plot for survival by passenger class
sns.barplot(x='Pclass', y='Survived', data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #e9ff70; font-size: 100%; text-align: left;">
# 📊This code snippet uses the Seaborn library to create a bar plot to visualize the survival rate by passenger class in the 'titanic' dataset.
#
# -The code `sns.barplot(x='Pclass', y='Survived', data=titanic)` creates a bar plot using the Seaborn `barplot()` function. The 'Pclass' column is used as the x-axis variable, and the 'Survived' column is used as the y-axis variable. The 'titanic' dataset is specified as the data source.
#
# -The resulting plot will show bars representing the survival rate for each passenger class. The height of each bar indicates the proportion of passengers who survived in that particular passenger class.
#
# -This visualization can provide insights into the relationship between passenger class and survival, allowing you to observe if there are any differences in survival rates among different passenger classes..🧐🔍
# </div>

# %%
#Box plot for fare by passenger class
sns.boxplot(x='Pclass', y='Fare', data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #f07167; font-size: 100%; text-align: left;">
# 📊This code snippet uses the Seaborn library to create a box plot to compare the fare distribution among different passenger classes in the 'titanic' dataset.
#
# -The code `sns.boxplot(x='Pclass', y='Fare', data=titanic)` creates a box plot using the Seaborn `boxplot()` function. The 'Pclass' column is used as the x-axis variable, and the 'Fare' column is used as the y-axis variable. The 'titanic' dataset is specified as the data source.
#
# -The resulting plot will show three boxes side by side, representing the fare distribution for each passenger class. Each box will have a horizontal line representing the median fare, a box representing the interquartile range, and whiskers representing the minimum and maximum values within 1.5 times the interquartile range.
#
# -This visualization can help identify any differences in fare distribution among different passenger classes, allowing you to observe if there are disparities in ticket prices based on passenger class..🧐🔍
# </div>

# %%
# Scatter plot for age vs fare
plt.scatter(titanic['Age'], titanic['Fare'])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Age vs Fare')
plt.show()

# %% [markdown]
# <div style="border-radius: 5px; border: #022b3a solid; padding: 10px; background-color: #70d6ff; font-size: 100%; text-align: left;">
# 📊This code snippet uses the Matplotlib library to create a scatter plot to visualize the relationship between age and fare in the 'titanic' dataset.
#
# -The code `plt.scatter(titanic['Age'], titanic['Fare'])` creates a scatter plot using the Matplotlib `scatter()` function. The 'Age' column is used as the x-axis variable, and the 'Fare' column is used as the y-axis variable. The data points will be plotted as individual dots on the graph.
#
# -The code `plt.xlabel('Age')` and `plt.ylabel('Fare')` add labels to the x-axis and y-axis, respectively.
#
# -The code `plt.title('Age vs Fare')` adds a title to the plot.
#
# -Finally, `plt.show()` is used to display the plot.
#
# -The resulting scatter plot will show the distribution of data points across age and fare values. This visualization can help identify any patterns or relationships between age and fare, such as if there is a correlation between age and the amount passengers paid for their tickets..🧐🔍
# </div>

# %% [markdown]
# # <p style="background-color:#00FF00;font-family:newtimeroman;color:black;font-size:250%;text-align:center;border-radius:10px 10px;"> " !! Thank You !!" " </p>
# <div style="text-align: center;">
#     <span style="font-size: 5em;">✔️</span>
# </div>
#
# <br>
#
# <div style="text-align: center;">
#    <span style="font-size: 1.4em; font-weight: bold; font-family: Arial; max-width:1200px; display: inline-block;">
#
#    </span>
# </div>
#
# <br>
#
# <br>
#
# <div style="text-align: center;">
#    <span style="font-size: 1.6em; font-weight: bold;font-family: Arial;"><a href="https://www.linkedin.com/in/mohamed-hamed-el-sayed-925a3824a/">"Linked In" Mohamed Hamed</a></span>
# </div>
